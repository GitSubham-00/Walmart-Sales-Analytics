# %% [markdown]
# # 🛒 Walmart Sales Data Analysis
# ### Analyst Simulation: Real-World Business Questions Answered with Python
#
# ---
#
# **Dataset:** `Walmart_Sales.csv`
# **Period:** February 2010 – October 2012
# **Stores:** 45 Walmart locations
# **Records:** 6,435 weekly entries
#
# ---
#
# ## 📋 Manager's Briefing
#
# > *"Hey, I need you to look into our sales data before Thursday's meeting. I need to know which stores are underperforming, whether holidays are driving sales, how unemployment affects us, and when our best and worst months are. Come back with actionable recommendations."*
# > — Senior Manager, Retail Analytics
#
# ---
#
# ## 📁 Table of Contents
#
# 1. [Import Libraries & Load Data](#section1)
# 2. [Store Performance Analysis](#section2)
# 3. [Holiday Impact on Sales](#section3)
# 4. [Economic Factors Analysis](#section4)
# 5. [Seasonal & Monthly Trends](#section5)
# 6. [Year-over-Year Growth](#section6)
# 7. [Store Volatility](#section7)
# 8. [Executive Summary & Recommendations](#section8)

# %% [markdown]
# ## Section 1: Import Libraries & Load Data <a id='section1'></a>

# %%
# Run the full analysis
# Make sure Walmart_Sales.csv is in the /data folder

import sys
sys.path.append('../src')

# Or simply run the script directly:
import subprocess
subprocess.run(['python', '../src/walmart_analyst_project.py'])

# %% [markdown]
# ---
# *For the full interactive version, open and run `../src/walmart_analyst_project.py`
# Charts will be saved to the `/charts` folder automatically.*
